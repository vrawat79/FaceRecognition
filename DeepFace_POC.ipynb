# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 1.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.6 MB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 95 kB 16.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 76 kB 16.3 MB/s eta 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 97 kB 19.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 12.6 MB/s eta 0:00:01
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14262 sha256=7cbf34f37c50e2dabb1ec9f2f590c1bc5edf5c04bed32bd98e7f0295bfbe5447
#   Stored in directory: /Users/vrawat/Library/Caches/pip/wheels/68/11/97/886e5796b655bf28bf4a0d75e933ea71c6d7d34be701168d1d
# Successfully built gdown
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# ...

# %%
from deepface import DeepFace
from matplotlib import pyplot

# %%
pixels = pyplot.imread(fname="IMG_2516.jpeg")    
pyplot.imshow(pixels)
pyplot.show()

pixels = pyplot.imread(fname="IMG_4101 copy.jpeg")    
pyplot.imshow(pixels)
pyplot.show()

# %%
verification = DeepFace.verify(img1_path="IMG_2516.jpeg", img2_path="IMG_4101 copy.jpeg")
verification
# Out:
# {'verified': False,
#  'distance': 0.5119329626836179,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}
